# %%
import pandas as pd
import os

# %%
train_data = pd.read_csv(os.path.join(os.path.split(os.getcwd())[0], "SYD_DAT_5/data/sydtrains.csv"))

# %%
train_data.describe()
# Out:
#               YEAR  IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# count  3367.000000   3367.000000    3367.000000   3367.000000    3367.000000
# mean   2009.013959     47.528958      29.364419   1061.749332    1010.986041
# std       3.164360     96.815978      78.484683   1480.814320    4061.525304
# min    2004.000000      0.000000       0.000000      0.000000       0.000000
# 25%    2006.000000     10.000000       0.000000     90.000000      20.000000
# 50%    2009.000000     20.000000      10.000000    460.000000     140.000000
# 75%    2012.000000     50.000000      20.000000   1430.000000     530.000000
# max    2014.000000    940.000000     920.000000  10630.000000   43210.000000
#
#        IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  IN_1830_0200  \
# count   3367.000000    3367.000000   3367.000000    3367.000000   3367.000000
# mean     712.803683     727.635878   1093.415503    1036.587467    324.359964
# ...

# %%
train_data2014 = train_data[train_data.YEAR==2014]

# %%
train_data2014
# Out:
#                             LINE                   STATION  YEAR  \
# 0                            CBD                   Central  2014
# 1                            CBD                 Town Hall  2014
# 2                            CBD                   Wynyard  2014
# 3                        Western                Parramatta  2014
# 4                    North Shore              North Sydney  2014
# 5                            CBD                   Redfern  2014
# 6                    North Shore                 Chatswood  2014
# 7                Eastern Suburbs            Bondi Junction  2014
# 8                     Inner West               Strathfield  2014
# 9                            CBD             Circular Quay  2014
# 10                           CBD              Martin Place  2014
# 11                     Illawarra                Hurstville  2014
# 12                   North Shore               St Leonards  2014
# ...

# %%
train_data2014.IN_0200_0600.idxmin()
# Out:
# 46

# %%
train_data2014.columns
# Out:
# Index([u'LINE', u'STATION', u'YEAR', u'SURVEY_DATE_USED', u'WHETHER_SURVEYED',
#        u'IN_0200_0600', u'OUT_0200_0600', u'IN_0600_0930', u'OUT_0600_0930',
#        u'IN_0930_1500', u'OUT_0930_1500', u'IN_1500_1830', u'OUT_1500_1830',
#        u'IN_1830_0200', u'OUT_1830_0200', u'IN_24_HOURS', u'OUT_24_HOURS',
#        u'RANK', u'STATION_SORT_ID'],
#       dtype='object')

# %%
train_data = pd.read_csv(os.path.join(os.path.split(os.getcwd())[0], "SYD_DAT_5/data/sydtrains.csv"), index_col=1)

# %%
train_data2014 = train_data[train_data.YEAR == 2014]

# %%
train_data2014.IN_0200_0600.idxmin()
# Out:
# 'Green Square'

# %%
train_data2014.IN_0200_0600.sum()
# Out:
# 16060

# %%
train_data2014
# Out:
#                                                  LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                           CBD  2014        6/05/2014
# Town Hall                                         CBD  2014        7/05/2014
# Wynyard                                           CBD  2014       20/05/2014
# Parramatta                                    Western  2014       19/11/2014
# North Sydney                              North Shore  2014       19/08/2014
# Redfern                                           CBD  2014        1/05/2014
# Chatswood                                 North Shore  2014       19/08/2014
# Bondi Junction                        Eastern Suburbs  2014        2/09/2014
# Strathfield                                Inner West  2014        9/09/2014
# Circular Quay                                     CBD  2014       22/05/2014
# Martin Place                                      CBD  2014       27/05/2014
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
train_data = pd.read_csv(os.path.join(os.path.split(os.getcwd())[0], "SYD_DAT_5/data/sydtrains.csv"), index_col=1, thousands=',')

# %%
train_data2014 = train_data[train_data.YEAR == 2014]

# %%
train_data2014.IN_24_HOURS
# Out:
# STATION
# Central                     97110
# Town Hall                   89620
# Wynyard                     60200
# Parramatta                  34960
# North Sydney                28610
# Redfern                     25680
# Chatswood                   22200
# Bondi Junction              21880
# Strathfield                 20710
# Circular Quay               20630
# Martin Place                20630
# Hurstville                  18290
# St Leonards                 17590
# Blacktown                   16560
# Burwood                     14990
# Kings Cross                 12870
# Hornsby                     12250
# Ashfield                    11200
# Kogarah                     11100
# Lidcombe                    10910
# Auburn                      10890
# Museum                      10860
# Epping                      10570
# Macquarie University        10090
# St James                     9850
# Rockdale                     9640
# Cabramatta                   8730
# ...

# %%
train_data2014
# Out:
#                                                  LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                           CBD  2014        6/05/2014
# Town Hall                                         CBD  2014        7/05/2014
# Wynyard                                           CBD  2014       20/05/2014
# Parramatta                                    Western  2014       19/11/2014
# North Sydney                              North Shore  2014       19/08/2014
# Redfern                                           CBD  2014        1/05/2014
# Chatswood                                 North Shore  2014       19/08/2014
# Bondi Junction                        Eastern Suburbs  2014        2/09/2014
# Strathfield                                Inner West  2014        9/09/2014
# Circular Quay                                     CBD  2014       22/05/2014
# Martin Place                                      CBD  2014       27/05/2014
# ...
